# %% [markdown]
# # Week 4 - Problem Set
#
# Practice what you learnt today with these problems; I will share the answers on Monday before the next workshop.

# %%
import numpy as np
import matplotlib.pyplot as plt
from utils_common import compute_model_output, generate_data
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# __1. In a markdown block, describe the role of training testing data in detecting if a machine learning model is overfitting or underfitting.__

# %% [markdown]
# In machine learning, training and testing data are crucial for evaluating whether a model is overfitting or underfitting. The training data is used to train the machine learning model. It helps the model learn patterns, relationships, and structures within the data. The testing data is used to evaluate the model's performance on unseen data. It serves as a proxy for how the model will perform in the real world. If the model performs exceptionally well on the training data but poorly on unseen data such as testing data, this is a sign of overfitting. Overfitting occurs when the model memorises the training data instead of generalising it to new data. If the model has low accuracy or high error rates even on the training data, it likely indicates underfitting. Underfitting occurs when the model is too simple to capture the underlying patterns in the data.

# %% [markdown]
# __2. In a markdown box, explain 'underfitting' using the below graph as a reference.__

# %%
fig, ax = plt.subplots()
x = np.linspace(10, -10, 100)
y = -x**2 + 4*x + 2  
x = x + np.random.uniform(-3, 3, size=x.shape)
y = y + np.random.uniform(-5, 5, size=y.shape)
ax.scatter(x, y, c='b', label='Training & Testing data')
x_lin = np.array([-10,10])
tmp_f_mb = compute_model_output(x_lin, 0, 0,)
ax.plot(x_lin, tmp_f_mb, c='r', label='ML Model')
ax.set_xticks([])
ax.set_xticklabels([])
ax.set_yticks([])
ax.set_yticklabels([])
plt.legend()
plt.show()

# %% [markdown]
# Underfitting in machine learning occurs when a model is too simplistic to capture the underlying patterns or structure of the data. This typically happens when the model is not complex enough to generalise well with the whole data set. The above training data is non-linear and appears to have a quadratic relationship. The ML Model is a simple linear model that only generalises well with the top of the parabola and generalises very poorly with the lowest points of the parabola.

# %% [markdown]
# __3. In a markdown box, explain bias and variance refering to the below model.__

# %%
fig, ax = plt.subplots()

x = x + np.random.uniform(-3, 3, size=x.shape)
y = y + np.random.uniform(-5, 5, size=y.shape)
ax.scatter(x, y, c='b', label='Training & Testing data')
x = np.linspace(13, -13, 100)
y = -x**2 + 4*x + 2  
ax.plot(x, y, c='r', label='ML Model')
ax.set_xticks([])
ax.set_xticklabels([])
ax.set_yticks([])
ax.set_yticklabels([])
plt.legend()
plt.show()

# %% [markdown]
# Bias refers to the error introduced by a model when it makes simplifying assumptions about the data. A low-bias model generalises well to the data, meaning it captures the complexities and patterns present in the dataset. The model shows low bias as it follows the quadratic pattern of the data without overfitting or underfitting the data, providing accurate predictions.
#
# Variance reflects how much a model's predictions change when trained on different subsets of the data. A high-variance model is overly complex, capturing noise as if it were part of the true pattern in the data, which leads to overfitting. This model has generalised to patterns and performed equally well on training data and unseen test data.
#
# The model demonstrates an optimal trade-off to strike a balance between bias and variance.

# %% [markdown]
# __4. In a markdown box, discuss the expected issues when evaluating a model with the training/testing split demonstrated in the graph below.__

# %%
m = generate_data(10, 55, 10, 55, 200, 0.7)
n = generate_data(0, 50, 0, 40, 50, 0.5)
plt.xlabel("Feature")
plt.ylabel("Target")
plt.scatter(m[0], m[1], color='yellow', label='Training Data')
plt.scatter(n[0], n[1], color='black', label='Testing Data')
plt.xticks([])
plt.yticks([])
plt.legend()
plt.show()

# %% [markdown]
# If the testing data and training data are not statistically similar, this mismatch, known as a 'data distribution shift', can significantly impact a machine learning model's performance. The model will learn patterns from the training data, which is more distributed with a higher mode and mean and has a more linear relationship and will make predictions from patterns in this data. The test data has less of a linear relationship and a different mode and mean. After the model is trained, if the testing data is used to evaluate it, the model will appear to poorly generalise to the unseeen testing, and The model will struggle to make accurate predictions or perform in real-world applications. Training testing split should have been performed using statically reliable methods like the training/testing split utilities in scikitlearn.

# %% [markdown]
# __5. In a code block, manually or procedurally, "one hot encode" this data, including wrangling the data to make the "Witches Cat" column consistent values.__
#
# | Colour | Animal | Witches Cat |
# | --- | --- | --- |
# | Black | Cat | Absolutely |
# | White | cat | Nein |
# | Brown | Cat | Never |
# | Black | Dog | Nope |
# | White | Dog | Negative |
# | Brown | Dog | Nah |

# %%
dataframe = pd.DataFrame({
    'Colour Black': [1, 0, 0, 1, 0, 0],
    'Colour Brown': [0, 1, 0, 0, 1, 0],
    'Colour White': [0, 0, 1, 0, 0, 1],
    'Animal Cat': [1, 1, 1, 0, 0, 0],
    'Animal Dog': [0, 0, 0, 1, 1, 1],
    'Target Witches Cat': [1, 0, 0, 0, 0, 0],
})

# %% [markdown]
# __6. For each set of data below, select the appropriate Matplotlib visualisation and plot them into a 1x3 row of subplots with labels, legends and colour coding where appropriate to the data.__

# %%
# Set 1
x0 = [1,2,3,4,5] # Feature 1  
y0 = [1,2,3,4,5] # Feature 2
target = [0,1,0,1,0] # Target

# Set 2
x1 = [10,8,6,4,2,0] # Feature    
y1 = [0,1,3,5,7,9]  # Target

# Set 3
x2 = np.array([[10],[8],[6],[4],[2],[0]]) # Feature
y2 = np.array([[10],[8],[6],[4],[2],[0]]) # Target
model = compute_model_output(x2, 1, 0,) # Model

fig, ax = plt.subplots(1,3, figsize=(15, 5))

ax[0].title.set_text("Set 1")
scatter = ax[0].scatter(x0, y0, c=target)
fig.colorbar(scatter, ax=ax[0], label='Target')
ax[0].set_xlabel("Feature 1")
ax[0].set_ylabel("Feature 2")

ax[1].title.set_text("Set 2")
ax[1].scatter(x1, y1, c='b')
ax[1].set_xlabel("Feature")
ax[1].set_ylabel("Target")

ax[2].title.set_text("Set 3")
ax[2].scatter(x2, y2, c='b')
ax[2].plot(x2, model, c='r', label='ML Model')
ax[2].legend()
ax[2].set_xlabel("Feature")
ax[2].set_ylabel("Target")

plt.show()

# %% [markdown]
# __7. Read '[ATO AI Models Draw Deep Scrutiny](https://www.itnews.com.au/news/atos-ai-models-draw-deep-scrutiny-615225)' and [Dept of health and aged care warns of AI biases](https://www.itnews.com.au/news/dept-of-health-and-aged-care-warns-of-ai-biases-608428). Then, in a markdown block, outline 2 types of AI/ML bias with reference to the articles.__

# %% [markdown]
# 1. Gender bias occurs when gender is overrepresented in the model because of biased training data, decisions in the design phase, or interpretation of the prediction. The ATO model was tested and found to be more likely to flag men for potential tax issues. The model was then evaluated and found to be fair, which would suggest that this is because, statistically, men are more likely to attempt tax evasion. Hence, the model is generalised to the training data and the real world.
# 2. Sample bias occurs when there's a problem with the data used to train the ML model. The Heath Department's skin cancer model was trained on mostly fair-skinned patients, so the sample was biased compared to the Australian population, which has a mix of skin colours. Thus, the model failed to generalise to the real world and was less accurate with darker-skinned individuals.

# %% [markdown]
# __8. Play [Survival of the best fit](https://www.survivalofthebestfit.com/).__
